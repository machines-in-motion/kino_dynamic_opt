# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np

import matplotlib.pyplot as plt

import time

from pymomentum import *

from PyDemoMomentumopt import MotionPlanner
from momentumopt.kinoptpy.momentum_kinematics_optimizer import MomentumKinematicsOptimizer

from quadruped.quadruped_wrapper import Quadruped12Wrapper

def replay_kinematic_plan():
    for ks in motion_planner.kin_optimizer.kinematics_sequence.kinematics_states:
        q = ks.robot_posture.generalized_joint_positions
        motion_planner.kin_optimizer.robot.display(np.matrix(q).T)
        time.sleep(0.1)

# %%
cfg_file = '../config/cfg_quadruped_dance_solo12.yaml'

motion_planner = MotionPlanner(cfg_file, RobotWrapper=Quadruped12Wrapper)
inv_kin = motion_planner.kin_optimizer.inv_kin
kin_opt = motion_planner.kin_optimizer

kin_opt.robot.ensureDisplay()
# Out:
# /home/jviereck/dev/learn_to_control_ws/workspace/src/catkin/control/kino-dynamic-opt/momentumopt/src/quadruped/quadruped_wrapper.py:225: DeprecatedWarning: Using deprecated instance variable Model.neutralConfiguration. Please use Model.referenceConfigurations instead.
#   self.q = self.robot.model.neutralConfiguration.copy()

# %%
motion_planner.optimize_dynamics(0)
motion_planner.optimize_kinematics(0)
motion_planner.replay_kinematics()
motion_planner.plot_centroidal()
# Out:
# ('DynOpt', 0)
# ('Dynopt - ', 1.4578919410705566)
# ('KinOpt', 0)
# Found initial configuration after 18 iterations
# ('kinopt - ', 0.10029411315917969)
# /home/jviereck/dev/learn_to_control_ws/workspace/src/catkin/control/kino-dynamic-opt/momentumopt/src/momentumopt/kinoptpy/momentum_kinematics_optimizer.py:242: DeprecatedWarning: Using deprecated instance variable Model.neutralConfiguration. Please use Model.referenceConfigurations instead.
#   q = self.robot.model.neutralConfiguration.copy()
# (<Figure size 432x576 with 3 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f40510da3d0>, <matplotlib.axes._subplots.AxesSubplot object at 0x7f4050e105d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4050dcb610>], dtype=object))

# %%
motion_planner.optimize_dynamics(1)
motion_planner.optimize_kinematics(1)
motion_planner.replay_kinematics()
motion_planner.plot_centroidal()
# Out:
# ('DynOpt', 1)
# ('Dynopt - ', 1.6359951496124268)
# ('KinOpt', 1)
# ('kinopt - ', 0.08326601982116699)
# (<Figure size 432x576 with 3 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f4050449ed0>, <matplotlib.axes._subplots.AxesSubplot object at 0x7f405043a110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f40503f5150>], dtype=object))

# %%
motion_planner.optimize_dynamics(2)
motion_planner.optimize_kinematics(2)
motion_planner.replay_kinematics()
motion_planner.plot_centroidal()
# Out:
# ('DynOpt', 2)
# ('Dynopt - ', 1.5746870040893555)
# ('KinOpt', 2)
# ('kinopt - ', 0.0834810733795166)
# (<Figure size 432x576 with 3 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f4050260310>, <matplotlib.axes._subplots.AxesSubplot object at 0x7f4050203710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f405023a750>], dtype=object))

# %%
motion_planner.optimize_dynamics(3)
motion_planner.optimize_kinematics(3)
motion_planner.replay_kinematics()
motion_planner.plot_centroidal()
# Out:
# ('DynOpt', 3)
# ('Dynopt - ', 1.5802838802337646)
# ('KinOpt', 3)
# ('kinopt - ', 0.0852210521697998)
# (<Figure size 432x576 with 3 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f4018336cd0>, <matplotlib.axes._subplots.AxesSubplot object at 0x7f40182f1390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f40182aa3d0>], dtype=object))

# %%
self = kin_opt

plan_joint_init_pos = self.planner_setting.get(
        PlannerVectorParam_KinematicDefaultJointPositions)

plan_joint_init_pos
# Out:
# array([ 0.  ,  0.52, -1.04,  0.  ,  0.52, -1.04,  0.  ,  0.52, -1.04,  0.  ,  0.52, -1.04])
